# %%
import numpy as np
array = np.array([1,3,4,2,9,6])

# %%
print(array > 4)
# Out:
# [False False False False  True  True]

# %%
2 < 6
# Out:
# True

# %%
a = np.array([7,5,3,1,9,0,2,4,6])
b = np.array([6,4,2,0,9,1,3,5,7])
print(a > b)
# Out:
# [ True  True  True  True False False False False False]

# %%
True == 1
# Out:
# True

# %%
True and False
# Out:
# False

# %%
x = 2; y = 6
x > 1 and y < 4
# Out:
# False

# %%
x > 1 or y < 4
# Out:
# True

# %%
not(x > 3)
# Out:
# True

# %%
np.logical_and(a > 2, b < 4)
# Out:
# array([False, False,  True, False, False, False, False, False, False], dtype=bool)

# %%
np.logical_or(a > 2, b < 4)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
np.logical_and(a > 2, a < 6)
# Out:
# array([False,  True,  True, False, False, False, False,  True, False], dtype=bool)

# %%
y = 7
if y > 7:
    print(str(y) + " es menor que 7")
elif y > 6:
    print(str(y) + " es menor que 6")
else:
    print(" y es " + str(y))
# Out:
# 7 es menor que 6

# %%
import pandas as pd
data = pd.read_csv('data_fanpage.csv')
print(data)
# Out:
#       id  social_network_account_id  social_network_account_followers  \
# 0     16                      38614                           1965664
# 1     19                      28990                            176909
# 2     20                      29189                           2032491
# 3      1                      35837                           1468492
# 4      5                      30603                            451471
# 5     37                      28613                            111700
# 6      7                      35875                           1466535
# 7     36                      30275                            229998
# 8     24                      25783                             25658
# 9     15                      29387                            900687
# 10    21                      29406                              2177
# 11    22                      26843                             16749
# ...

# %%
data["code_iso"] #data.loc[:,[code_iso]]
# Out:
# 0      PE
# 1      PE
# 2      PE
# 3      MX
# 4      GT
# 5      CO
# 6      CO
# 7      MX
# 8      CO
# 9      PE
# 10     CO
# 11     CO
# 12     CO
# 13     PE
# 14     CO
# 15     CO
# 16     CO
# 17     CO
# 18     MX
# 19     CO
# 20     CO
# 21     PE
# 22     CO
# 23     PE
# 24     PE
# 25     PE
# 26     PE
# 27     PE
# 28     PE
# 29     PE
#        ..
# 694    PE
# 695    CO
# 696    CO
# 697    MX
# 698    CO
# 699    MX
# 700    PE
# 701    CO
# 702    MX
# 703    CO
# 704    PE
# 705    CO
# 706    MX
# 707    CO
# 708    CO
# 709    MX
# 710    MX
# 711    CO
# 712    MX
# 713    MX
# 714    CO
# 715    MX
# 716    PE
# 717    CO
# 718    CO
# 719    PE
# 720    PE
# 721    US
# 722    MX
# 723    PE
# Name: code_iso, dtype: object

# %%
pe=data["code_iso"]=="PE"
print(pe)
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 694     True
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# 700     True
# 701    False
# 702    False
# 703    False
# 704     True
# 705    False
# 706    False
# 707    False
# 708    False
# 709    False
# 710    False
# 711    False
# 712    False
# 713    False
# 714    False
# 715    False
# 716     True
# 717    False
# 718    False
# 719     True
# 720     True
# 721    False
# 722    False
# 723     True
# Name: code_iso, dtype: bool

# %%
data[pe]
# Out:
#       id  social_network_account_id  social_network_account_followers  \
# 0     16                      38614                           1965664
# 1     19                      28990                            176909
# 2     20                      29189                           2032491
# 9     15                      29387                            900687
# 13    18                      31083                           1466515
# 21    14                      29546                             14665
# 23    38                      29492                            135018
# 24    39                      36330                             14728
# 25    40                      28248                             30675
# 26    41                      28464                            107963
# 27    42                      28208                             18245
# 28    43                      29221                             59057
# ...

# %%
data[data["code_iso"] == "PE"]
# Out:
#       id  social_network_account_id  social_network_account_followers  \
# 0     16                      38614                           1965664
# 1     19                      28990                            176909
# 2     20                      29189                           2032491
# 9     15                      29387                            900687
# 13    18                      31083                           1466515
# 21    14                      29546                             14665
# 23    38                      29492                            135018
# 24    39                      36330                             14728
# 25    40                      28248                             30675
# 26    41                      28464                            107963
# 27    42                      28208                             18245
# 28    43                      29221                             59057
# ...

# %%
pe_f = data[np.logical_and(data["social_network_account_followers"] > 0, data["code_iso"] == "PE")]
pe_f.shape
# Out:
# (156, 17)
